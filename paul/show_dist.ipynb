# %%
import matplotlib.pyplot as plt
plt.figure()
plt.title('different hybrid function')
plt.plot(['ar','bn','es','fa','fi','fr','hi','id','ja','ko','ru','sw','te','th','zh'],
[0.6723,0.6546,0.6377,0.5898,0.6744,0.5208,0.6218,0.4471,0.5735,0.5951,0.5274,0.4662,0.6592,0.5942,0.5636],label='aBM25+(1-a)mDPR ,a=0.08')
plt.plot(['ar','bn','es','fa','fi','fr','hi','id','ja','ko','ru','sw','te','th','zh'],
[0.6779,0.6612,0.6398,0.5764,0.6780,0.5126,0.6175,0.4673,0.5757,0.5920,0.5210,0.4650,0.6654,0.6041,0.5277],label='log(aBM25+1)+(1-a)log(mDPR+1) ,a=0.14')
plt.plot(['ar','bn','es','fa','fi','fr','hi','id','ja','ko','ru','sw','te','th','zh'],
[0.4831,0.5128,0.3280,0.3334,0.5534,0.1765,0.4578,0.4486,0.3689,0.4190,0.3342,0.3924,0.5062,0.4874,0.1801],label='BM25')
plt.plot(['ar','bn','es','fa','fi','fr','hi','id','ja','ko','ru','sw','te','th','zh'],
[0.4993,0.4427,0.4777,0.4800,0.4721,0.4352,0.3830,0.2719,0.4390,0.4189,0.4073,0.2990,0.3557,0.3578,0.5116],label='mDPR',c='yellow')
plt.legend()
plt.ylabel('nDCG@10')
plt.grid()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.figure()
plt.title('')
diff=np.array([0.4831,0.5128,0.3280,0.3334,0.5534,0.1765,0.4578,0.4486,0.3689,0.4190,0.3342,0.3924,0.5062,0.4874,0.1801])\
    -np.array([0.4809,0.5079,0.3193,0.3334,0.5513,0.1832,0.4578,0.4486,0.3689,0.4190,0.3342,0.3826,0.4942,0.4838,0.1801])
plt.bar(['ar','bn','es','fa','fi','fr','hi','id','ja','ko','ru','sw','te','th','zh'],
diff,label='BM25_13% - BM25')
plt.legend()
plt.ylabel('nDCG@10')
plt.grid()
plt.show()
